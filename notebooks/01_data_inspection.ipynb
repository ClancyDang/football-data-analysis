# %%
import pandas as pd

# %%
df=pd.read_csv("../data/English Premier League - Player Stats - 24:25/epl_player_stats_24_25.csv")

# %%
df.head()
# Out:
#      Player Name     Club Nationality Position  Appearances  Minutes  Goals  \
# 0      Ben White  Arsenal     England      DEF           17     1198      0
# 1    Bukayo Saka  Arsenal     England      MID           25     1735      6
# 2     David Raya  Arsenal       Spain      GKP           38     3420      0
# 3    Declan Rice  Arsenal     England      MID           35     2833      4
# 4  Ethan Nwaneri  Arsenal     England      MID           26      889      4
#
#    Assists  Shots  Shots On Target  ... Fouls  Yellow Cards  Red Cards  Saves  \
# 0        2      9               12  ...    10             2          0      0
# 1       10     67                2  ...    15             3          0      0
# 2        0      0                0  ...     1             3          0     86
# 3        7     48               18  ...    21             5          1      0
# 4        0     24                0  ...     9             1          0      0
#
# ...

# %%
df.columns
# Out:
# Index(['Player Name', 'Club', 'Nationality', 'Position', 'Appearances',
#        'Minutes', 'Goals', 'Assists', 'Shots', 'Shots On Target',
#        'Conversion %', 'Big Chances Missed', 'Hit Woodwork', 'Offsides',
#        'Touches', 'Passes', 'Successful Passes', 'Passes%', 'Crosses',
#        'Successful Crosses', 'Crosses %', 'fThird Passes',
#        'Successful fThird Passes', 'fThird Passes %', 'Through Balls',
#        'Carries', 'Progressive Carries', 'Carries Ended with Goal',
#        'Carries Ended with Assist', 'Carries Ended with Shot',
#        'Carries Ended with Chance', 'Possession Won', 'Dispossessed',
#        'Clean Sheets', 'Clearances', 'Interceptions', 'Blocks', 'Tackles',
#        'Ground Duels', 'gDuels Won', 'gDuels %', 'Aerial Duels', 'aDuels Won',
#        'aDuels %', 'Goals Conceded', 'xGoT Conceded', 'Own Goals', 'Fouls',
#        'Yellow Cards', 'Red Cards', 'Saves', 'Saves %', 'Penalties Saved',
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 562 entries, 0 to 561
# Data columns (total 57 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Player Name                562 non-null    str
#  1   Club                       562 non-null    str
#  2   Nationality                562 non-null    str
#  3   Position                   562 non-null    str
#  4   Appearances                562 non-null    int64
#  5   Minutes                    562 non-null    int64
#  6   Goals                      562 non-null    int64
#  7   Assists                    562 non-null    int64
#  8   Shots                      562 non-null    int64
#  9   Shots On Target            562 non-null    int64
#  10  Conversion %               562 non-null    str
#  11  Big Chances Missed         562 non-null    int64
#  12  Hit Woodwork               562 non-null    int64
#  13  Offsides                   562 non-null    int64
# ...

# %%
df.describe()
# Out:
#        Appearances      Minutes       Goals     Assists       Shots  \
# count   562.000000   562.000000  562.000000  562.000000  562.000000
# mean     20.581851  1336.208185    1.713523    1.145907   17.526690
# std      12.136239  1055.099340    3.310674    2.197891   22.342341
# min       1.000000     1.000000    0.000000    0.000000    0.000000
# 25%      10.000000   336.750000    0.000000    0.000000    1.000000
# 50%      22.000000  1156.000000    0.000000    0.000000   10.000000
# 75%      32.000000  2229.250000    2.000000    2.000000   25.000000
# max      38.000000  3420.000000   29.000000   18.000000  130.000000
#
#        Shots On Target  Big Chances Missed  Hit Woodwork    Offsides  \
# count       562.000000          562.000000    562.000000  562.000000
# mean          5.514235            2.135231      0.496441    2.250890
# std           9.407054            3.732051      0.986986    4.085456
# min           0.000000            0.000000      0.000000    0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Player Name                  0
# Club                         0
# Nationality                  0
# Position                     0
# Appearances                  0
# Minutes                      0
# Goals                        0
# Assists                      0
# Shots                        0
# Shots On Target              0
# Conversion %                 0
# Big Chances Missed           0
# Hit Woodwork                 0
# Offsides                     0
# Touches                      0
# Passes                       0
# Successful Passes            0
# Passes%                      0
# Crosses                      0
# Successful Crosses           0
# Crosses %                    0
# fThird Passes                0
# Successful fThird Passes     0
# fThird Passes %              0
# Through Balls                0
# Carries                      0
# Progressive Carries          0
# Carries Ended with Goal      0
# Carries Ended with Assist    0
# Carries Ended with Shot      0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Player Name                      str
# Club                             str
# Nationality                      str
# Position                         str
# Appearances                    int64
# Minutes                        int64
# Goals                          int64
# Assists                        int64
# Shots                          int64
# Shots On Target                int64
# Conversion %                 float64
# Big Chances Missed             int64
# Hit Woodwork                   int64
# Offsides                       int64
# Touches                        int64
# Passes                         int64
# Successful Passes              int64
# Passes%                          str
# Crosses                        int64
# Successful Crosses             int64
# Crosses %                        str
# fThird Passes                  int64
# Successful fThird Passes       int64
# fThird Passes %                  str
# Through Balls                  int64
# ...

# %%
df.nunique()
# Out:
# Player Name                  562
# Club                          21
# Nationality                   64
# Position                       4
# Appearances                   38
# Minutes                      482
# Goals                         19
# Assists                       14
# Shots                         83
# Shots On Target               43
# Conversion %                  32
# Big Chances Missed            23
# Hit Woodwork                   7
# Offsides                      23
# Touches                      474
# Passes                       267
# Successful Passes            270
# Passes%                       35
# Crosses                       83
# Successful Crosses            29
# Crosses %                     43
# fThird Passes                219
# Successful fThird Passes     217
# fThird Passes %               46
# Through Balls                 23
# Carries                      216
# Progressive Carries          190
# Carries Ended with Goal        8
# ...

# %%
df["Conversion %"] = df["Conversion %"].str.rstrip('%').astype(float)

# %%
df["Conversion %"].head()
# Out:
# 0    13.0
# 1    25.0
# 2     0.0
# 3    15.0
# 4     0.0
# Name: Conversion %, dtype: float64

# %%
df["Conversion %"].dtypes
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# Player Name                      str
# Club                             str
# Nationality                      str
# Position                         str
# Appearances                    int64
# Minutes                        int64
# Goals                          int64
# Assists                        int64
# Shots                          int64
# Shots On Target                int64
# Conversion %                 float64
# Big Chances Missed             int64
# Hit Woodwork                   int64
# Offsides                       int64
# Touches                        int64
# Passes                         int64
# Successful Passes              int64
# Passes%                          str
# Crosses                        int64
# Successful Crosses             int64
# Crosses %                        str
# fThird Passes                  int64
# Successful fThird Passes       int64
# fThird Passes %                  str
# Through Balls                  int64
# ...

# %%
percentage_cols = [
    "Passes%",
    "Crosses %",
    "fThird Passes %",
    "gDuels %",
    "aDuels %",
    "Saves %"
]

for col in percentage_cols:
    df[col] = df[col].str.rstrip('%').astype(float)

# %%
df[percentage_cols].dtypes
# Out:
# Passes%            float64
# Crosses %          float64
# fThird Passes %    float64
# gDuels %           float64
# aDuels %           float64
# Saves %            float64
# dtype: object

# %%
df.to_csv("../data/English Premier League - Player Stats - 24:25/epl_player_stats_24_25_cleaned.csv", index=False)
