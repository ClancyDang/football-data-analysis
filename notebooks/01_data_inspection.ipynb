# %%
import pandas as pd

# %%
df=pd.read_csv("../data/English Premier League - Player Stats - 24:25/epl_player_stats_24_25.csv")

# %%
df[["Player Name", "Goals"]].head()
# Out:
#      Player Name  Goals
# 0      Ben White      0
# 1    Bukayo Saka      6
# 2     David Raya      0
# 3    Declan Rice      4
# 4  Ethan Nwaneri      4

# %%
df[
    (df["Minutes"] > 900) &
    (df["Position"] == "FWD")
    ][["Player Name", "Club", "Position", "Minutes", "Goals"]].head(30)
# Out:
#                Player Name                    Club Position  Minutes  Goals
# 11             Kai Havertz                 Arsenal      FWD     1874      9
# 46           Ollie Watkins             Aston Villa      FWD     2610     16
# 61               Evanilson             Bournemouth      FWD     2335      0
# 107            Yoane Wissa               Brentford      FWD     2927     19
# 116          Danny Welbeck  Brighton & Hove Albion      FWD     2122     10
# 127             João Pedro  Brighton & Hove Albion      FWD     1953     10
# 129           Kaoru Mitoma  Brighton & Hove Albion      FWD     2608     10
# 155        Nicolas Jackson                 Chelsea      FWD     2238     10
# 178          Eddie Nketiah          Crystal Palace      FWD     1026      3
# 180   Jean-Philippe Mateta          Crystal Palace      FWD     2654     14
# 194         Adam Armstrong                 Everton      FWD     1252      2
# ...

# %%
df["Conversion %"] = df["Conversion %"].str.rstrip("%").astype(float)

# %%
df[
    (df["Shots"] > 5) &
    (df["Conversion %"] > 10)
]
# Out:
#               Player Name                     Club    Nationality Position  \
# 0               Ben White                  Arsenal        England      DEF
# 1             Bukayo Saka                  Arsenal        England      MID
# 3             Declan Rice                  Arsenal        England      MID
# 6       Gabriel Magalhães                  Arsenal         Brazil      DEF
# 10         Jurriën Timber                  Arsenal    Netherlands      DEF
# ..                    ...                      ...            ...      ...
# 519         Lucas Paquetá          West Ham United         Brazil      MID
# 522     Maximilian Kilman          West Ham United        England      DEF
# 538      Emmanuel Agbadou  Wolverhampton Wanderers  Cote D’Ivoire      DEF
# 543  Jørgen Strand Larsen  Wolverhampton Wanderers         Norway      FWD
# 548         Matheus Cunha  Wolverhampton Wanderers         Brazil      MID
#
# ...

# %%
forwards = df[
    (df["Minutes"] > 900)
    ].to_clipboard(index=False, header=True)

# %%
filtered_df = df[
    (df["Minutes"] >= 900) &
    (df["Position"] == "FWD")
]

filtered_df.to_excel("forwards_900min.xlsx", index=False)

# %%
df[
    (df["Minutes"] >= 900) &
    (df["Position"] == "FWD")
][["Player Name", "Club", "Position", "Goals", "Assists", "Shots", "Conversion %"]]
# Out:
#                Player Name                     Club Position  Goals  Assists  \
# 11             Kai Havertz                  Arsenal      FWD      9        3
# 46           Ollie Watkins              Aston Villa      FWD     16        8
# 61               Evanilson              Bournemouth      FWD      0        1
# 107            Yoane Wissa                Brentford      FWD     19        0
# 116          Danny Welbeck   Brighton & Hove Albion      FWD     10        0
# 127             João Pedro   Brighton & Hove Albion      FWD     10        0
# 129           Kaoru Mitoma   Brighton & Hove Albion      FWD     10        4
# 155        Nicolas Jackson                  Chelsea      FWD     10        5
# 178          Eddie Nketiah           Crystal Palace      FWD      3        0
# 180   Jean-Philippe Mateta           Crystal Palace      FWD     14        2
# 194         Adam Armstrong                  Everton      FWD      2        2
# ...

# %%
df[
    (df["Shots"] >= 40) &
    (df["Conversion %"] >= 15)
]
# Out:
#                 Player Name                     Club    Nationality Position  \
# 1               Bukayo Saka                  Arsenal        England      MID
# 3               Declan Rice                  Arsenal        England      MID
# 61                Evanilson              Bournemouth         Brazil      FWD
# 66          Justin Kluivert              Bournemouth    Netherlands      MID
# 141             Cole Palmer                  Chelsea        England      MID
# 142          Enzo Fernández                  Chelsea      Argentina      MID
# 199   Dominic Calvert-Lewin                  Everton        England      FWD
# 288             Jamie Vardy           Leicester City        England      FWD
# 315      Dominik Szoboszlai                Liverpool        Hungary      MID
# 326  Trent Alexander-Arnold                Liverpool        England      DEF
# 335          Erling Haaland          Manchester City         Norway      FWD
# ...

# %%
df[
    (df["Minutes"] >= 900) &
    (df["Shots"] >= 50)
].sort_values("Shots", ascending=False)
# Out:
#                Player Name                     Club     Nationality Position  \
# 324          Mohamed Salah                Liverpool           Egypt      MID
# 141            Cole Palmer                  Chelsea         England      MID
# 54         Antoine Semenyo              Bournemouth           Ghana      MID
# 548          Matheus Cunha  Wolverhampton Wanderers          Brazil      MID
# 335         Erling Haaland          Manchester City          Norway      FWD
# 177           Eberechi Eze           Crystal Palace         England      MID
# 391         Alexander Isak         Newcastle United          Sweden      FWD
# 367        Bruno Fernandes        Manchester United        Portugal      MID
# 236           Raúl Jiménez                   Fulham          Mexico      FWD
# 107            Yoane Wissa                Brentford        DR Congo      FWD
# 514           Jarrod Bowen          West Ham United         England      MID
# ...

# %%
df[
    (df["Minutes"] < 300) &
    (df["Conversion %"] > 10)
]
# Out:
# Empty DataFrame
# Columns: [Player Name, Club, Nationality, Position, Appearances, Minutes, Goals, Assists, Shots, Shots On Target, Conversion %, Big Chances Missed, Hit Woodwork, Offsides, Touches, Passes, Successful Passes, Passes%, Crosses, Successful Crosses, Crosses %, fThird Passes, Successful fThird Passes, fThird Passes %, Through Balls, Carries, Progressive Carries, Carries Ended with Goal, Carries Ended with Assist, Carries Ended with Shot, Carries Ended with Chance, Possession Won, Dispossessed, Clean Sheets, Clearances, Interceptions, Blocks, Tackles, Ground Duels, gDuels Won, gDuels %, Aerial Duels, aDuels Won, aDuels %, Goals Conceded, xGoT Conceded, Own Goals, Fouls, Yellow Cards, Red Cards, Saves, Saves %, Penalties Saved, Clearances Off Line, Punches, High Claims, Goals Prevented]
# Index: []
#
# [0 rows x 57 columns]

# %%
df[
    df["Club"] == "Arsenal"
][["Player Name", "Position", "Minutes", "Goals", "Assists", "Shots"]].sort_values("Shots", ascending=False)
# Out:
#               Player Name Position  Minutes  Goals  Assists  Shots
# 13       Leandro Trossard      MID     2550      8        7     72
# 1             Bukayo Saka      MID     1735      6       10     67
# 7      Gabriel Martinelli      MID     2300      8        4     55
# 11            Kai Havertz      FWD     1874      9        3     53
# 14        Martin Ødegaard      MID     2328      3        8     49
# 3             Declan Rice      MID     2833      4        7     48
# 15           Mikel Merino      MID     1581      7        2     38
# 23          Thomas Partey      MID     2799      4        0     26
# 4           Ethan Nwaneri      MID      889      4        0     24
# 6       Gabriel Magalhães      DEF     2365      3        1     22
# 5           Gabriel Jesus      FWD      603      3        0     20
# 10         Jurriën Timber      DEF     2422      1        3     14
# 20        Raheem Sterling      MID      496      0        2     11
# ...

# %%
df[
    (df["Position"] == "FWD") | 
    (df["Position"] == "MID") 
]
# Out:
#             Player Name                     Club Nationality Position  \
# 1           Bukayo Saka                  Arsenal     England      MID
# 3           Declan Rice                  Arsenal     England      MID
# 4         Ethan Nwaneri                  Arsenal     England      MID
# 5         Gabriel Jesus                  Arsenal      Brazil      FWD
# 7    Gabriel Martinelli                  Arsenal      Brazil      MID
# ..                  ...                      ...         ...      ...
# 547         Mateus Mané  Wolverhampton Wanderers     England      MID
# 548       Matheus Cunha  Wolverhampton Wanderers      Brazil      MID
# 552       Pablo Sarabia  Wolverhampton Wanderers       Spain      MID
# 555       Rodrigo Gomes  Wolverhampton Wanderers    Portugal      MID
# 559         Tommy Doyle  Wolverhampton Wanderers     England      MID
#
#      Appearances  Minutes  Goals  Assists  Shots  Shots On Target  ...  Fouls  \
# ...

# %%
df["Club"].nunique()
# Out:
# 21

# %%
df["Club"].unique()
# Out:
# <StringArray>
# [                'Arsenal',             'Aston Villa',
#              'Bournemouth',               'Brentford',
#                 'Brighton',  'Brighton & Hove Albion',
#                  'Chelsea',          'Crystal Palace',
#                  'Everton',                  'Fulham',
#             'Ipswich Town',          'Leicester City',
#                'Liverpool',         'Manchester City',
#        'Manchester United',        'Newcastle United',
#        'Nottingham Forest',             'Southampton',
#        'Tottenham Hotspur',         'West Ham United',
#  'Wolverhampton Wanderers']
# Length: 21, dtype: str

# %%
regular_forwards = df[
    (df["Position"] == "FWD") &
    (df["Minutes"] >= 900)
]

len(regular_forwards)
# Out:
# 36
